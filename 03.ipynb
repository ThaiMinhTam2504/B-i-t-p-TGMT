# %%
#Import thư viện
from PIL import Image
from imgtools import *

# %%
#Đường dẫn ảnh
my_path=r'C:/Users/ADMIN/Pictures/MEME/doremon.jpg'

# %%
#Đọc ảnh
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x612>

# %%
#Kích thước ban đầu
print(img.size)
# Out:
# (600, 612)

# %%
#Thay đổi kích thước
new_size=(1000,1000)
new_image=img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
#Lưu ảnh

# %%
#Thay đổi kích thước
thumbnail_size=(50,50)
img.thumbnail(thumbnail_size)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=49x50>

# %%
dir= r'C:/Users/ADMIN/Pictures/MEME'
new_img_01=dir+'/test.JPG'
img.save(new_img_01)

# %%
display(new_img_01)
# Out:
# 'C:/Users/ADMIN/Pictures/MEME/test.JPG'
