# %%
#import thư viện
from PIL import Image
from imgtools import *

# %%
#đường dẫn ảnh
my_path= r'C:/Users/ADMIN/Pictures/MEME/doremon.jpg'

# %%
#đọc ảnh
img=load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x612>

# %%
#xoay ảnh
rotated_image=img.rotate(270)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x612>

# %%
#transpose ảnh
transposed_image=img.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=RGB size=612x600>
